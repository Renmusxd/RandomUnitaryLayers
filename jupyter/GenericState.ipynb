# %%
import numpy
import py_entropy
from matplotlib import pyplot

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,12))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=False)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=False)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
# Out:
# 178 µs ± 685 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 38 µs ± 95.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 1.06 ms ± 1.47 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 141 µs ± 92.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 3.92 ms ± 8.57 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 433 µs ± 1.86 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 21.1 ms ± 89.2 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.14 ms ± 1.53 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 83.1 ms ± 353 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 8.06 ms ± 8.98 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 422 ms ± 1.33 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 42 ms ± 90.8 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.63 s ± 2.17 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 157 ms ± 182 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time])
pyplot.plot(Ls, [x.average for x in pre_time])
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.show()

pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,12))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=True)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=True)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
# Out:
# 159 µs ± 3.34 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 145 µs ± 2.03 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 405 µs ± 4.56 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 332 µs ± 3.29 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 749 µs ± 11.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 461 µs ± 8.11 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.5 ms ± 62.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 972 µs ± 19.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 7.61 ms ± 53.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.87 ms ± 14.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 35.1 ms ± 380 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 9.88 ms ± 57.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 132 ms ± 224 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 51.6 ms ± 328 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time])
pyplot.plot(Ls, [x.average for x in pre_time])
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.show()

pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,14))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=False)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=False)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
    
par_sizes = []
par_no_pre_time = []
par_pre_time = []

for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=True)
    par_sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    par_no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=True)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    par_pre_time.append(ret)
# Out:
# 27 µs ± 121 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 14.2 µs ± 25.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 136 µs ± 351 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 37.4 µs ± 93.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 227 µs ± 698 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 50.8 µs ± 41.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 1.35 ms ± 1.64 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 202 µs ± 99.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 2.43 ms ± 15.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 339 µs ± 577 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 12.9 ms ± 21.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.66 ms ± 5.65 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 23.5 ms ± 151 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.02 ms ± 15.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 122 ms ± 398 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 14.9 ms ± 34.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 229 ms ± 746 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 29 ms ± 60.2 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 92.1 µs ± 614 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 92.6 µs ± 508 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 201 µs ± 1.2 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 188 µs ± 845 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 233 µs ± 4.91 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 218 µs ± 3.64 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 522 µs ± 2.41 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 424 µs ± 4.37 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 642 µs ± 7.91 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 476 µs ± 3.87 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 1.82 ms ± 15.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 928 µs ± 8.08 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.78 ms ± 74.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.18 ms ± 10.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 11.2 ms ± 43.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.23 ms ± 59.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20.4 ms ± 557 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.67 ms ± 144 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time], label='Std')
pyplot.plot(Ls, [x.average for x in pre_time], label='Pre')
pyplot.plot(Ls, [x.average for x in par_no_pre_time], label='Par Std')
pyplot.plot(Ls, [x.average for x in par_pre_time], label='Par Pre')
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.legend()
pyplot.show()


pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

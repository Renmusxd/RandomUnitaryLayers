# %%
import numpy
import py_entropy
from matplotlib import pyplot

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,12))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=False)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=False)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
# Out:
# 181 µs ± 488 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 36.9 µs ± 308 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 1.08 ms ± 6.89 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 132 µs ± 1.41 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 4.06 ms ± 4.68 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 392 µs ± 12 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 21.5 ms ± 152 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.88 ms ± 10.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 83.2 ms ± 458 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 7.05 ms ± 79 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 435 ms ± 12.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 39 ms ± 407 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.7 s ± 8.39 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 140 ms ± 1.39 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time])
pyplot.plot(Ls, [x.average for x in pre_time])
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.show()

pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,12))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=True)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=True)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
# Out:
# 165 µs ± 2.61 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 169 µs ± 9.55 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 480 µs ± 21.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 391 µs ± 16.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 856 µs ± 19.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 505 µs ± 12 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.68 ms ± 96.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.08 ms ± 26.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 8.37 ms ± 98 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.12 ms ± 88.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 39.1 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 11.8 ms ± 293 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 137 ms ± 978 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 56.4 ms ± 579 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time])
pyplot.plot(Ls, [x.average for x in pre_time])
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.show()

pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,14))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=False)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=False)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
    
par_sizes = []
par_no_pre_time = []
par_pre_time = []

for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=True)
    par_sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    par_no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=True)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    par_pre_time.append(ret)
# Out:
# 26 µs ± 351 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 13.8 µs ± 278 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 138 µs ± 349 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 36.9 µs ± 64.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 228 µs ± 813 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 50.6 µs ± 135 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 1.33 ms ± 1.26 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 202 µs ± 649 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.41 ms ± 15.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 341 µs ± 1.43 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 12.9 ms ± 15.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.62 ms ± 25.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 23.2 ms ± 147 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.97 ms ± 71.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 121 ms ± 433 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 15.2 ms ± 9.62 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 226 ms ± 1.54 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 28.4 ms ± 88.8 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 92.9 µs ± 537 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 93.4 µs ± 515 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 201 µs ± 1.96 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 190 µs ± 830 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 239 µs ± 3.47 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 218 µs ± 3.79 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 528 µs ± 4.81 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 431 µs ± 4.12 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 663 µs ± 7.27 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 483 µs ± 5.68 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 1.85 ms ± 8.06 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 951 µs ± 7.56 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.84 ms ± 41.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.19 ms ± 6.24 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 11.3 ms ± 82.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.24 ms ± 42.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20.2 ms ± 44.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.43 ms ± 74.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time], label='Std')
pyplot.plot(Ls, [x.average for x in pre_time], label='Pre')
pyplot.plot(Ls, [x.average for x in par_no_pre_time], label='Par Std')
pyplot.plot(Ls, [x.average for x in par_pre_time], label='Par Pre')
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.legend()
pyplot.show()


pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

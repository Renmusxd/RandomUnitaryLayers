# %%
import numpy
import py_entropy
from matplotlib import pyplot

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,12))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=False)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=False)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
# Out:
# 226 µs ± 658 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 49 µs ± 117 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 1.34 ms ± 3.64 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 207 µs ± 185 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 5.06 ms ± 21.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 672 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 26.9 ms ± 45.2 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.38 ms ± 2.61 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 104 ms ± 154 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 12.7 ms ± 35.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 523 ms ± 2.55 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 64.5 ms ± 136 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.05 s ± 8.05 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 247 ms ± 827 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time])
pyplot.plot(Ls, [x.average for x in pre_time])
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.show()

pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,12))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=True)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i, [1,2,1], parallel_matrix_mul=True)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
# Out:
# 161 µs ± 5.29 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 150 µs ± 1.86 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 409 µs ± 6.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 337 µs ± 9.68 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 846 µs ± 45.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 487 µs ± 8.56 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.94 ms ± 48.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.19 ms ± 21.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 9.36 ms ± 54.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.68 ms ± 62.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 43.6 ms ± 333 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 11.4 ms ± 440 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 166 ms ± 888 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 48.4 ms ± 272 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time])
pyplot.plot(Ls, [x.average for x in pre_time])
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.show()

pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()

# %%
sizes = []
no_pre_time = []
pre_time = []

Ls = list(range(5,14))
for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=False)
    sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=False)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    pre_time.append(ret)
    
par_sizes = []
par_no_pre_time = []
par_pre_time = []

for i in Ls:
    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=True)
    par_sizes.append(g.get_precompute_size())
    ret = %timeit -o g.apply_layer()
    par_no_pre_time.append(ret)

    g = py_entropy.GenericMultiDefectState(i, i//2, [1,2], parallel_matrix_mul=True)
    g.precompute_connections()
    ret = %timeit -o g.apply_layer()
    par_pre_time.append(ret)
# Out:
# 33.2 µs ± 801 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 16 µs ± 28.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 190 µs ± 22.1 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 47.2 µs ± 281 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 292 µs ± 809 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 67.3 µs ± 351 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 1.67 ms ± 3.36 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 293 µs ± 5.51 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3 ms ± 12.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 508 µs ± 955 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 16.1 ms ± 38.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.54 ms ± 9.46 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 29.9 ms ± 78.4 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.66 ms ± 16.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 151 ms ± 173 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 22.6 ms ± 88.9 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 285 ms ± 1.05 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 43.9 ms ± 134 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 89.5 µs ± 295 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 93.6 µs ± 6.22 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 231 µs ± 43.4 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 223 µs ± 42.5 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 235 µs ± 4.17 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 215 µs ± 2.81 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 552 µs ± 10.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 436 µs ± 3.85 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 703 µs ± 6.72 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 506 µs ± 4.17 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 2.17 ms ± 55.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.1 ms ± 11.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.4 ms ± 68.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.51 ms ± 12.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 14.3 ms ± 31.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.79 ms ± 208 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 26.5 ms ± 656 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 8.39 ms ± 250 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
pyplot.plot(Ls, [x.average for x in no_pre_time], label='Std')
pyplot.plot(Ls, [x.average for x in pre_time], label='Pre')
pyplot.plot(Ls, [x.average for x in par_no_pre_time], label='Par Std')
pyplot.plot(Ls, [x.average for x in par_pre_time], label='Par Pre')
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Time to Run')
pyplot.legend()
pyplot.show()


pyplot.plot(Ls, sizes)
pyplot.yscale('log')
pyplot.xlabel('L')
pyplot.ylabel('Precompute Memory Cost')
pyplot.show()
